# %%
from combined import Combined

# %%
Combined.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
# 'Natural Language Processing'

# %%
Combined.OddEven(52452)
# Out:
# Enter a number: 52452
# 52452 is Even number

# %%
Combined.Elegible("male",20)
# Out:
# Your Gender:Male
# Your Age:20
# NOT ELIGIBLE

# %%
Combined.percentage()
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total : 468
# Percentage : 93.6

# %%
Combined.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area Formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle:  10
