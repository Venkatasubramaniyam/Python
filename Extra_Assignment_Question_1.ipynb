# %%
#print Statement

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
# Buy input

# %%
ins=str(input("Enter your institute name? :"))
# Out:
# Enter your institute name? : HOPE AI

# %%
#Buy inputs

# %%
name=str(input("Enter your name:"))
age=int(input("Enter your age:"))
school=str(input("Enter your school name:"))
deg=str(input("Enter your degree:"))
# Out:
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your degree: B.E CSE

# %%
#Addition

# %%
add1=int(input("a="))
add2=int(input("b="))
print("add =",add1+add2)
# Out:
# a= 43
# b= 34
# add = 77

# %%
#Subtraction

# %%
sub1=int(input("a="))
sub2=int(input("b="))
print("Sub =",sub1-sub2)
# Out:
# a= 43
# b= 34
# Sub = 9

# %%
#Multiplication

# %%
mul1=int(input("a="))
mul2=int(input("b="))
print("Mul =",mul1*mul2)
# Out:
# a= 63
# b= 97
# Mul = 6111

# %%
#Division

# %%
div1=int(input("a="))
div2=int(input("b="))
print("Float Div =",div1/div2)
# Out:
# a= 76
# b= 31
# Float Div = 2.4516129032258065

# %%
#Floor division

# %%
fdiv1=int(input("a="))
fdiv2=int(input("b="))
print("Floor Div =",fdiv1//fdiv2)
# Out:
# a= 76
# b= 31
# Floor Div = 2

# %%
#Modulo

# %%
mod1=int(input("a="))
mod2=int(input("b="))
print("Modulo =",mod1%mod2)
# Out:
# a= 76
# b= 31
# Modulo = 14

# %%
#Power

# %%
pow1=int(input("a="))
pow2=int(input("b="))
print("Power =",pow1**pow2)
# Out:
# a= 4
# b= 4
# Power = 256
